# %%
# Multivariable Calculus - Fourth Edition
# by James Stewart

# %%
# Chapter 11 -
# 11.4 Polar Coordinates

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import math

# %%
# Test polar plot
r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r, color = "#FF007F")
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
# The Curve r = cos 2 * theta, in both cartesian and polar plots.
# The polar plot is a four-leaved rose.

# %%
# I am fancy in Los Angeles, I brought the world, I brought NYC, if I go, it all goes.  
# Love me or lose me and everything that all my mirror and my presence brought and built.

matplotlib.rcParams.update({'font.size': 18})

f,ax=plt.subplots(figsize=(18,8))
x=np.linspace(0, 2*np.pi, 1001)
y=np.cos(2*x)

ax.plot(x/np.pi,y, color = "#FF007F")
ax.set(xlabel='r (π)', ylabel='θ',
       title='r = cos 2θ in Cartesian Coordinates')

plt.axhline(0,color='black') 
plt.axvline(0,color='black')

ax.grid(color='grey', linestyle='-', linewidth=0.5, )

#ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%g $\pi$'))
#ax.xaxis.set_major_locator(ticker.MultipleLocator(base=1.0))

plt.show()

# %%
matplotlib.rcParams.update({'font.size': 12})

theta = np.arange(0, 2 * np.pi, .01)[1:]
r = np.cos(2* theta)

fig = plt.figure()
ax = fig.add_subplot(polar=True)
ax.set(title='r = cos 2θ on Polar Plot')


# change negative r values to positive, rotating theta by 180º
theta = np.where(r >= 0, theta, theta + np.pi)
r = np.abs(r)
ax.plot(theta, r, color = "#FF007F",  linestyle = '-')

plt.show()

# %%
matplotlib.rcParams.update({'font.size': 12})

theta = np.arange(0, 10 * np.pi, .01)[1:]
r = np.sin((8*theta)/5)

fig = plt.figure()
ax = fig.add_subplot(polar=True)
ax.set(title='r = cos 2θ on Polar Plot')


# change negative r values to positive, rotating theta by 180º
theta = np.where(r >= 0, theta, theta + np.pi)
r = np.abs(r)
ax.plot(theta, r, color = "#FF007F",  linestyle = '-')

plt.show()

# %%
# Question 51) Show that the polar curve r = 4 + 2 sec(θ) (called a conchoid) has the line x = 2
# as a vertical asymptote by showing that the limit as r to pos and neg infinity is x = 2.  Use this fact to help
# sketch the conchoid.

# %%
# Question 57 - 62, Find the slope of the tangent line to the given polar curve at the point specified by the 
# value θ.

# %%
# I am reteaching myself right now. I had multivar in 2003, twenty whole years ago. Python and matplotlib didn't 
# exist, we still had software mailed to us on CDs.  Yeah, I'm that old.

# 57
# r = 3 cos θ, θ = Pi/3
from numpy import sqrt

matplotlib.rcParams.update({'font.size': 12})

theta = np.arange(0, 10 * np.pi, .01)[1:]
r = 3*(np.cos(theta))
line = 1/sqrt(3)

fig = plt.figure()
ax = fig.add_subplot(polar=True)
ax.set(title='r = 3cos(θ) on Polar Plot')


# change negative r values to positive, rotating theta by 180º
theta = np.where(r >= 0, theta, theta + np.pi)
r = np.abs(r)
ax.plot(theta, r, color = "#FF007F",  linestyle = '-')

ax.plot(line, color = "blue",  linestyle = '-')

plt.show()

# %% [markdown]
# I have tried to figure out how to plot the tangent here in matplot lib.  I have calculated the slope, but have not
# figure that out yet.

# %%
import sympy as sy
